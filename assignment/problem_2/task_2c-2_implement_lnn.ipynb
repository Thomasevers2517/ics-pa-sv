# %% [markdown]
# # RO47019: Intelligent Control Systems Practical Assignment
# * Period: 2023-2024, Q3
# * Course homepage: https://brightspace.tudelft.nl/d2l/home/500969
# * Instructor: Cosimo Della Santina (C.DellaSantina@tudelft.nl)
# * Teaching assistant: Maria de Neves de Fonseca (M.deNevesdeFonseca-1@student.tudelft.nl)
# * (c) TU Delft, 2024
#
# Make sure you fill in any place that says `YOUR CODE HERE` or `YOUR ANSWER HERE`. Remove `raise NotImplementedError()` afterwards. Moreover, if you see an empty cell, please DO NOT delete it, instead run that cell as you would run all other cells. Please fill in your name(s) and other required details below:

# %%
# Please fill in your names, student numbers, netID, and emails below.
STUDENT_1_NAME = "Thomas Evers"
STUDENT_1_STUDENT_NUMBER = "5310121"
STUDENT_1_NETID = "thomasevers"
STUDENT_1_EMAIL = "t.evers-2@student.tudelft.nl"

# %%
# Note: this block is a check that you have filled in the above information.
# It will throw an AssertionError until all fields are filled
assert STUDENT_1_NAME != ""
assert STUDENT_1_STUDENT_NUMBER != ""
assert STUDENT_1_NETID != ""
assert STUDENT_1_EMAIL != ""

# %% [markdown]
# ### General announcements
#
# * Do *not* share your solutions (also after the course is finished), and do *not* copy solutions from others. By submitting your solutions, you claim that you alone are responsible for this code.
#
# * Do *not* email questions directly, since we want to provide everybody with the same information and avoid repeating the same answers. Instead, please post your questions regarding this assignment in the correct support forum on Brightspace, this way everybody can benefit from the response. If you do have a particular question that you want to ask directly, please use the scheduled Q&A hours to ask the TA.
#
# * There is a strict deadline for each assignment. Students are responsible to ensure that they have uploaded their work in time. So, please double check that your upload succeeded to the Brightspace and avoid any late penalties.
#
# * This [Jupyter notebook](https://jupyter.org/) uses `nbgrader` to help us with automated tests. `nbgrader` will make various cells in this notebook "uneditable" or "unremovable" and gives them a special id in the cell metadata. This way, when we run our checks, the system will check the existence of the cell ids and verify the number of points and which checks must be run. While there are ways that you can edit the metadata and work around the restrictions to delete or modify these special cells, you should not do that since then our nbgrader backend will not be able to parse your notebook and give you points for the assignment. You are free to add additional cells, but if you find a cell that you cannot modify or remove, please know that this is on purpose.
#
# * This notebook will have in various places a line that throws a `NotImplementedError` exception. These are locations where the assignment requires you to adapt the code! These lines are just there as a reminder for you that you have not yet adapted that particular piece of code, especially when you execute all the cells. Once your solution code replaced these lines, it should accordingly *not* throw any exceptions anymore.
#
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).

# %% [markdown]
# # Task 2c.2 - Implementation of a Lagrangian Neural Network (LNN) (9p)
#
# **Author:** Maximilian Stölzle (M.W.Stolzle@tudelft.nl)
#
# This notebook will guide you through the implementation of a Lagrangian neural network.

# %%
import sys
sys.path.append("C:/Users/thoma/OneDrive - Delft University of Technology/Documenten/UNI/Intelligent Control/ics-pa-sv")

# %%
# Reloads the python files outside of this notebook automatically
# %load_ext autoreload
# %autoreload 2

# import all Python modules
from distutils.util import strtobool
from functools import partial
from jax import config as jax_config

jax_config.update("jax_platform_name", "cpu")  # set default device to 'cpu'
jax_config.update("jax_enable_x64", True)  # double precision
import jax
from jax import random
from jax import numpy as jnp
import os
from pathlib import Path
import warnings

from jax_double_pendulum.integrators import rk4_step
from jax_double_pendulum.utils import normalize_link_angles

# define boolean to check if the notebook is run for the purposes of autograding
AUTOGRADING = strtobool(os.environ.get("AUTOGRADING", "false"))
# define tolerances for grading
RTOL = float(os.environ.get("RTOL", "1e-4"))  # relative tolerance
ATOL = float(os.environ.get("ATOL", "1e-7"))  # absolute tolerance

# %% [markdown]
# ## Neural networks (2p)
#
# First, please finish the implementation of the neural networks `MassMatrixNN` and `PotentialEnergyNN`. Both neural networks should consist of four layers and have the following structure:
#
# 1. A linear layer mapping from the input dimension to the hidden state dimension $n_\mathrm{hidden}$.
#
# 2. A softplus activation function.
#
# 3. A linear layer with $n_\mathrm{hidden}$ as both the input and output dimension.
#
# 4. A softplus activation function.
#
# 5. A linear layer with $n_\mathrm{hidden}$ as both the input and output dimension.
#
# 6. A softplus activation function.
#
# 7. A linear layer with $n_\mathrm{hidden}$ as both the input and output dimension.
#
# 8. A softplus activation function.
#
# 9. A linear layer mapping from $n_\mathrm{hidden}$ to the output dimension.
#
#
# The hidden state dimension is set by the `num_hidden` attribute of the class to $32$. The softplus activation function is a smooth approximation of the Rectified Linear Unit (ReLU) function.
#
# The mass matrix $M$ (sometimes also denoted as $B$) of mechanical systems has two important characteristics, which we want to enforce for our learned mass matrix as well:
#
# - The diagonal values are always positive
# - The matrix is symmetric
#
# The symmetry is given automatically by the fact that we only learn a triangular matrix and then derive the complete mass matrix from that triangular matrix. We can induce the first characteristic by applying a softplus activation function in conjunction with a shifting of the diagonals.

# %%
# DO NOT REMOVE OR MODIFY THIS CELL

# import MassMatrixNN and PotentialEnergyNN from lnn.ipynb
from ipynb.fs.full.lnn import MassMatrixNN, PotentialEnergyNN

# initialize the PRNG key at seed 0
_rng = random.PRNGKey(seed=0)

# initialize parameters of MassMatrixNN by passing a dummy input of ones through the network
_mass_matrix_nn_params = MassMatrixNN().init(_rng, jnp.ones((2,)))["params"]

# initialize parameters of PotentialEnergyNN by passing a dummy input of ones through the network
_potential_energy_nn_params = PotentialEnergyNN().init(_rng, jnp.ones((2,)))["params"]

# some dummy system state
_th = 0* jnp.ones((2,))

_M_nn = MassMatrixNN().apply({"params": _mass_matrix_nn_params}, _th)
print("Computed mass matrix (output from neural network):\n", _M_nn)

_M_nn_target = jnp.array([[0.54595144, -0.53372961], [-0.53372961, 0.97476694]])
print("Target mass matrix (output from neural network):\n", _M_nn_target)
if not jnp.allclose(_M_nn, _M_nn_target, rtol=RTOL, atol=ATOL):
    warnings.warn("The output of the mass matrix neural network is not correct.")

_U = PotentialEnergyNN().apply({"params": _potential_energy_nn_params}, _th)
print("Computed potential energy:\n", _U)

_U_target = jnp.array(-0.3061547720368191)
print("Target potential energy:\n", _U_target)
if not jnp.allclose(_U, _U_target, rtol=RTOL, atol=ATOL):
    warnings.warn("The output of the potential energy neural network is not correct.")
# Out:
# Computed mass matrix (output from neural network):
#  [[ 0.54595144 -0.53372961]
#  [-0.53372961  0.97476694]]
# Target mass matrix (output from neural network):
#  [[ 0.54595144 -0.53372961]
#  [-0.53372961  0.97476694]]
# Computed potential energy:
#  [-0.30615477]
# Target potential energy:
#  -0.3061547720368191

# %% [markdown]
# ## Lagrangian (1p)
#
# First, please implement the two functions `kinetic_energy_fn` and `potential_energy_fn` which compute the (estimated) kinetic energy and potential energy of the system respectively:
#
# \begin{equation}
#     \mathcal{T} = \frac{1}{2} \: \dot{\theta}^\mathrm{T} \: f_\mathrm{M}(\theta, \pi_\mathrm{M}) \: \dot{\theta},
#     \qquad
#     \mathcal{U} = f_\mathcal{U}(\theta, \pi_\mathcal{U}),
# \end{equation}
#
# where $f_\mathrm{M}(\theta, \pi_\mathrm{M})$ and $f_\mathcal{U}(\theta, \pi_\mathcal{U})$ are the two neural network forward functions respectively.
#
# The Lagrangian $\mathcal{L}$ is then defined as
#
# \begin{equation}
#     \mathcal{L} = \mathcal{T} - \mathcal{U},
# \end{equation}
#
# and needs to be implemented into `lagrangian_fn`.

# %%
# DO NOT REMOVE OR MODIFY THIS CELL

# import lagrangian_fn from lnn.ipynb
from ipynb.fs.full.lnn import lagrangian_fn

# dummy link velocity
_th_d = jnp.pi * jnp.ones((2,))

_L = lagrangian_fn(
    _mass_matrix_nn_params,
    _potential_energy_nn_params,
    _th,
    _th_d,
)
print("Computed Lagrangian:", _L)

_L_target = jnp.array(2.542899071686838)
print("Target Lagrangian:", _L_target)
if not jnp.allclose(_L, _L_target, rtol=RTOL, atol=ATOL):
    warnings.warn("The computed Lagrangian is not correct.")
# Out:
# T:Traced<ShapedArray(float64[])>with<DynamicJaxprTrace(level=2/0)>
# ---------------------------------------------------------------------------
# ScopeParamShapeError                      Traceback (most recent call last)
# Cell In[6], line 9
#       6 # dummy link velocity
#       7 _th_d = jnp.pi * jnp.ones((2,))
# ----> 9 _L = lagrangian_fn(
#      10     _mass_matrix_nn_params,
#      11     _potential_energy_nn_params,
#      12     _th,
#      13     _th_d,
#      14 )
#      15 print("Computed Lagrangian:", _L)
#      17 _L_target = jnp.array(2.542899071686838)
#
#     [... skipping hidden 12 frame]
#
# File c:\Users\thoma\OneDrive - Delft University of Technology\Documenten\UNI\Intelligent Control\ics-pa-sv\assignment\problem_2\lnn.ipynb:261, in lagrangian_fn(mass_matrix_nn_params, potential_energy_nn_params, th, th_d)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "id": "ac408b5e",
#       6    "metadata": {
#       7     "deletable": false,
#       8     "editable": false,
#       9     "nbgrader": {
#      10      "cell_type": "markdown",
#      11      "checksum": "7619294def77410a539e618e2428f0d5",
#      12      "grade": false,
#      13      "grade_id": "cell-b00828259c8e42e8",
#      14      "locked": true,
#      15      "schema_version": 3,
#      16      "solution": false,
#      17      "task": false
#      18     }
#      19    },
#      20    "source": [
#      21     "# RO47019: Intelligent Control Systems Practical Assignment\n",
#      22     "* Period: 2023-2024, Q3\n",
#      23     "* Course homepage: https://brightspace.tudelft.nl/d2l/home/500969\n",
#      24     "* Instructor: Cosimo Della Santina (C.DellaSantina@tudelft.nl)\n",
#      25     "* Teaching assistant: Maria de Neves de Fonseca (M.deNevesdeFonseca-1@student.tudelft.nl)\n",
#      26     "* (c) TU Delft, 2024\n",
#      27     "\n",
#      28     "Make sure you fill in any place that says `YOUR CODE HERE` or `YOUR ANSWER HERE`. Remove `raise NotImplementedError()` afterwards. Moreover, if you see an empty cell, please DO NOT delete it, instead run that cell as you would run all other cells. Please fill in your name(s) and other required details below:"
#      29    ]
#      30   },
#      31   {
#      32    "cell_type": "code",
#      33    "execution_count": 15,
#      34    "id": "4f9e220c",
#      35    "metadata": {},
#      36    "outputs": [],
#      37    "source": [
#      38     "# Please fill in your names, student numbers, netID, and emails below.\n",
#      39     "STUDENT_1_NAME = \"Thomas Evers\"\n",
#      40     "STUDENT_1_STUDENT_NUMBER = \"5310121\"\n",
#      41     "STUDENT_1_NETID = \"thomasevers\"\n",
#      42     "STUDENT_1_EMAIL = \"t.evers-2@student.tudelft.nl\""
#      43    ]
#      44   },
#      45   {
#      46    "cell_type": "code",
#      47    "execution_count": 16,
#      48    "id": "8ba32571",
#      49    "metadata": {
#      50     "deletable": false,
#      51     "editable": false,
#      52     "nbgrader": {
#      53      "cell_type": "code",
#      54      "checksum": "042927213b84aa368aa3ea72caa4cb60",
#      55      "grade": true,
#      56      "grade_id": "cell-9f148ec62e0de49c",
#      57      "locked": true,
#      58      "points": 0,
#      59      "schema_version": 3,
#      60      "solution": false,
#      61      "task": false
#      62     }
#      63    },
#      64    "outputs": [],
#      65    "source": [
#      66     "# Note: this block is a check that you have filled in the above information.\n",
#      67     "# It will throw an AssertionError until all fields are filled\n",
#      68     "assert STUDENT_1_NAME != \"\"\n",
#      69     "assert STUDENT_1_STUDENT_NUMBER != \"\"\n",
#      70     "assert STUDENT_1_NETID != \"\"\n",
#      71     "assert STUDENT_1_EMAIL != \"\""
#      72    ]
#      73   },
#      74   {
#      75    "cell_type": "markdown",
#      76    "id": "af317a94",
#      77    "metadata": {
#      78     "deletable": false,
#      79     "editable": false,
#      80     "nbgrader": {
#      81      "cell_type": "markdown",
#      82      "checksum": "95c5b11f9ac3896252d342cabb38d867",
#      83      "grade": false,
#      84      "grade_id": "cell-4ea391677951116c",
#      85      "locked": true,
#      86      "schema_version": 3,
#      87      "solution": false,
#      88      "task": false
#      89     }
#      90    },
#      91    "source": [
#      92     "### General announcements\n",
#      93     "\n",
#      94     "* Do *not* share your solutions (also after the course is finished), and do *not* copy solutions from others. By submitting your solutions, you claim that you alone are responsible for this code.\n",
#      95     "\n",
#      96     "* Do *not* email questions directly, since we want to provide everybody with the same information and avoid repeating the same answers. Instead, please post your questions regarding this assignment in the correct support forum on Brightspace, this way everybody can benefit from the response. If you do have a particular question that you want to ask directly, please use the scheduled Q&A hours to ask the TA.\n",
#      97     "\n",
#      98     "* There is a strict deadline for each assignment. Students are responsible to ensure that they have uploaded their work in time. So, please double check that your upload succeeded to the Brightspace and avoid any late penalties.\n",
#      99     "\n",
#     100     "* This [Jupyter notebook](https://jupyter.org/) uses `nbgrader` to help us with automated tests. `nbgrader` will make various cells in this notebook \"uneditable\" or \"unremovable\" and gives them a special id in the cell metadata. This way, when we run our checks, the system will check the existence of the cell ids and verify the number of points and which checks must be run. While there are ways that you can edit the metadata and work around the restrictions to delete or modify these special cells, you should not do that since then our nbgrader backend will not be able to parse your notebook and give you points for the assignment. You are free to add additional cells, but if you find a cell that you cannot modify or remove, please know that this is on purpose.\n",
#     101     "\n",
#     102     "* This notebook will have in various places a line that throws a `NotImplementedError` exception. These are locations where the assignment requires you to adapt the code! These lines are just there as a reminder for you that you have not yet adapted that particular piece of code, especially when you execute all the cells. Once your solution code replaced these lines, it should accordingly *not* throw any exceptions anymore.\n",
#     103     "\n",
#     104     "Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\\rightarrow$Run All)."
#     105    ]
#     106   },
#     107   {
#     108    "cell_type": "code",
#     109    "execution_count": 17,
#     110    "id": "3c956945",
#     111    "metadata": {},
#     112    "outputs": [],
#     113    "source": [
#     114     "import sys\n",
#     115     "sys.path.append(\"C:/Users/thoma/OneDrive - Delft University of Technology/Documenten/UNI/Intelligent Control/ics-pa-sv\")"
#     116    ]
#     117   },
#     118   {
#     119    "cell_type": "markdown",
#     120    "id": "387d2c60",
#     121    "metadata": {
#     122     "deletable": false,
#     123     "editable": false,
#     124     "nbgrader": {
#     125      "cell_type": "markdown",
#     126      "checksum": "7a3b42b2fb38c185d4bbc65fbe1c7f8d",
#     127      "grade": false,
#     128      "grade_id": "cell-ed88010142fb94bb",
#     129      "locked": true,
#     130      "schema_version": 3,
#     131      "solution": false,
#     132      "task": false
#     133     }
#     134    },
#     135    "source": [
#     136     "# Lagrangian Neural Network (LNN)\n",
#     137     "\n",
#     138     "**Author:** Maximilian Stölzle (M.W.Stolzle@tudelft.nl)\n",
#     139     "\n",
#     140     "This notebook will contain functions for implementing a Lagrangian neural network. Please follow the notebook `task_2c-2_lnn_implementation.ipynb`, which guides you through these implementations."
#     141    ]
#     142   },
#     143   {
#     144    "cell_type": "code",
#     145    "execution_count": 18,
#     146    "id": "c5a29eaa",
#     147    "metadata": {
#     148     "deletable": false,
#     149     "editable": false,
#     150     "nbgrader": {
#     151      "cell_type": "code",
#     152      "checksum": "2d6635d3a20ea7ea4643049a39727636",
#     153      "grade": false,
#     154      "grade_id": "cell-6d73deac900e51cb",
#     155      "locked": true,
#     156      "schema_version": 3,
#     157      "solution": false,
#     158      "task": false
#     159     }
#     160    },
#     161    "outputs": [],
#     162    "source": [
#     163     "from flax import linen as nn\n",
#     164     "from flax.core import FrozenDict\n",
#     165     "from functools import partial\n",
#     166     "from jax import config as jax_config\n",
#     167     "\n",
#     168     "jax_config.update(\"jax_platform_name\", \"cpu\")  # set default device to 'cpu'\n",
#     169     "jax_config.update(\"jax_enable_x64\", True)  # double precision\n",
#     170     "import jax\n",
#     171     "from jax import Array, jit, debug\n",
#     172     "import jax.numpy as jnp\n",
#     173     "import numpy as np\n",
#     174     "from typing import Dict, Tuple\n",
#     175     "\n",
#     176     "from jax_double_pendulum.integrators import rk4_step\n",
#     177     "from jax_double_pendulum.utils import normalize_link_angles"
#     178    ]
#     179   },
#     180   {
#     181    "cell_type": "code",
#     182    "execution_count": 19,
#     183    "id": "f23c573c",
#     184    "metadata": {
#     185     "deletable": false,
#     186     "nbgrader": {
#     187      "cell_type": "code",
#     188      "checksum": "dfa37c5c2491b941a85ee5f38abf8550",
#     189      "grade": false,
#     190      "grade_id": "cell-90677efa4e583357",
#     191      "locked": false,
#     192      "schema_version": 3,
#     193      "solution": true,
#     194      "task": false
#     195     }
#     196    },
#     197    "outputs": [],
#     198    "source": [
#     199     "class MassMatrixNN(nn.Module):\n",
#     200     "    \"\"\"\n",
#     201     "    Neural network to approximate the mass matrix.\n",
#     202     "    \"\"\"\n",
#     203     "\n",
#     204     "    num_hidden: int = 32  # Number of hidden units per intermediate layer\n",
#     205     "\n",
#     206     "    diagonal_shift = 0.001  # shifting the diagonal before activation function\n",
#     207     "    diagonal_eps = 0.002  # small value added to the resulting diagonal\n",
#     208     "\n",
#     209     "    @nn.compact\n",
#     210     "    def __call__(self, th: Array) -> Array:\n",
#     211     "        \"\"\"\n",
#     212     "        Evaluate the mass matrix for the current neural network parameters\n",
#     213     "        Args:\n",
#     214     "            th: link angles of shape (2, ).\n",
#     215     "                We assume that the link angles are already normalized to the interval [-pi, pi].\n",
#     216     "        Returns:\n",
#     217     "            M: mass matrix of shape (2, 2)\n",
#     218     "        \"\"\"\n",
#     219     "        num_dof = th.shape[-1]  # Degrees of Freedom of the robot\n",
#     220     "        num_nn_outputs = int((num_dof**2 + num_dof) / 2)\n",
#     221     "\n",
#     222     "        # implement the neural network layers\n",
#     223     "        # use nn.Dense and nn.softplus layers\n",
#     224     "        # the output of the last layer needs to be saved in the variable `m`\n",
#     225     "        # the elements of the triangular matrix are the outputs of the network\n",
#     226     "        m = jnp.zeros((num_nn_outputs,))\n",
#     227     "        full_layer1 = nn.Dense(self.num_hidden)\n",
#     228     "        full_layer2 = nn.Dense(self.num_hidden)\n",
#     229     "        full_layer3 = nn.Dense(self.num_hidden)\n",
#     230     "        full_layer4 = nn.Dense(self.num_hidden)\n",
#     231     "        output_layer= nn.Dense(features=num_nn_outputs)\n",
#     232     "        \n",
#     233     "        x = full_layer1(th)\n",
#     234     "        x = nn.activation.softplus(x)\n",
#     235     "        x = full_layer2(x)\n",
#     236     "        x = nn.activation.softplus(x)\n",
#     237     "        x = full_layer3(x)\n",
#     238     "        x = nn.activation.softplus(x)\n",
#     239     "        x = full_layer4(x)\n",
#     240     "        x = nn.activation.softplus(x)\n",
#     241     "        m = output_layer(x)\n",
#     242     "\n",
#     243     "\n",
#     244     "        # split-off the first num_dof as the diagonal entries\n",
#     245     "        l_diagonal, l_off_diagonal = jnp.split(\n",
#     246     "            m,\n",
#     247     "            np.array(\n",
#     248     "                [\n",
#     249     "                    num_dof,\n",
#     250     "                ]\n",
#     251     "            ),\n",
#     252     "            axis=-1,\n",
#     253     "        )\n",
#     254     "\n",
#     255     "        # ensure positive diagonal\n",
#     256     "        # first, add `self.diagonal_shift` to the diagonal\n",
#     257     "        l_diagonal = l_diagonal + self.diagonal_shift\n",
#     258     "        \n",
#     259     "        # then, apply softplus\n",
#     260     "        l_diagonal = nn.softplus(l_diagonal)\n",
# --> 261     "        \n",
#     262     "        # finally, add `self.diagonal_eps` to the diagonal\n",
#     263     "        l_diagonal = l_diagonal + self.diagonal_eps\n",
#     264     "        \n",
#     265     "\n",
#     266     "        # Calculate the indices of the diagonal elements of L:\n",
#     267     "        indices_diag = np.arange(num_dof, dtype=int) + 1\n",
#     268     "        indices_diag = (indices_diag * (indices_diag + 1) / 2 - 1).astype(int)  # [0, 2]\n",
#     269     "        # Calculate the indices of the off-diagonal elements of L:\n",
#     270     "        indices_off_diag = np.setdiff1d(np.arange(num_nn_outputs), indices_diag)  # [1]\n",
#     271     "        # Indexing for concatenation of l_diagonal and l_off_diagonal\n",
#     272     "        indices_nn_output = np.hstack((indices_diag, indices_off_diag))  # [0, 2, 1]\n",
#     273     "\n",
#     274     "        # vector of lower triangular matrix (i.e. flattened lower triangular matrix)\n",
#     275     "        vec_tril = jnp.concatenate([l_diagonal, l_off_diagonal], axis=-1)[\n",
#     276     "            ..., indices_nn_output\n",
#     277     "        ]\n",
#     278     "\n",
#     279     "        # construct empty triangular matrix\n",
#     280     "        tril_mat = jnp.zeros((num_dof, num_dof))\n",
#     281     "        # (i, j) indices of lower triangular matrix\n",
#     282     "        indices_tril = np.tril_indices(num_dof)  # (array([0, 1, 1]), array([0, 0, 1]))\n",
#     283     "        # populate triangular matrix from vector\n",
#     284     "        tril_mat = tril_mat.at[indices_tril].set(vec_tril[:])\n",
#     285     "\n",
#     286     "        # construct mass matrix from triangular matrix\n",
#     287     "        M = tril_mat @ tril_mat.transpose()\n",
#     288     "        assert M.shape == (2, 2)\n",
#     289     "\n",
#     290     "        return M"
#     291    ]
#     292   },
#     293   {
#     294    "cell_type": "code",
#     295    "execution_count": 20,
#     296    "id": "a6974402",
#     297    "metadata": {
#     298     "deletable": false,
#     299     "nbgrader": {
#     300      "cell_type": "code",
#     301      "checksum": "94a5da4d394415a8d6c56a8b18a35386",
#     302      "grade": false,
#     303      "grade_id": "cell-e2583bbbc2ae1715",
#     304      "locked": false,
#     305      "schema_version": 3,
#     306      "solution": true,
#     307      "task": false
#     308     }
#     309    },
#     310    "outputs": [],
#     311    "source": [
#     312     "class PotentialEnergyNN(nn.Module):\n",
#     313     "    \"\"\"\n",
#     314     "    Neural network to approximate the potential energy.\n",
#     315     "    \"\"\"\n",
#     316     "\n",
#     317     "    num_hidden: int = 32  # Number of hidden units per intermediate layer\n",
#     318     "\n",
#     319     "    @nn.compact\n",
#     320     "    def __call__(self, th: Array) -> Array:\n",
#     321     "        \"\"\"\n",
#     322     "        Evaluate the potential energy for the current neural network parameters\n",
#     323     "        Args:\n",
#     324     "            th: link angles of shape (2, ).\n",
#     325     "                We assume that the link angles are already normalized to the interval [-pi, pi].\n",
#     326     "        Returns:\n",
#     327     "            U: potential energy of shape ( )\n",
#     328     "        \"\"\"\n",
#     329     "        \n",
#     330     "\n",
#     331     "        full_layer1 = nn.Dense(self.num_hidden)\n",
#     332     "        full_layer2 = nn.Dense(self.num_hidden)\n",
#     333     "        full_layer3 = nn.Dense(self.num_hidden)\n",
#     334     "        full_layer4 = nn.Dense(self.num_hidden)\n",
#     335     "        output_layer = nn.Dense(features=1)\n",
#     336     "        x = full_layer1(th)\n",
#     337     "        x = nn.activation.softplus(x)\n",
#     338     "        x = full_layer2(x)\n",
#     339     "        x = nn.activation.softplus(x)\n",
#     340     "        x = full_layer3(x)\n",
#     341     "        x = nn.activation.softplus(x)\n",
#     342     "        x = full_layer4(x)\n",
#     343     "        x = nn.activation.softplus(x)\n",
#     344     "        U = output_layer(x)\n",
#     345     "        assert U.shape == (1,)\n",
#     346     "        return U"
#     347    ]
#     348   },
#     349   {
#     350    "cell_type": "code",
#     351    "execution_count": 21,
#     352    "id": "2f406274",
#     353    "metadata": {
#     354     "deletable": false,
#     355     "nbgrader": {
#     356      "cell_type": "code",
#     357      "checksum": "7969d4d05c8963b360eaefc6904212b2",
#     358      "grade": false,
#     359      "grade_id": "cell-a63dfc33b5289c23",
#     360      "locked": false,
#     361      "schema_version": 3,
#     362      "solution": true,
#     363      "task": false
#     364     }
#     365    },
#     366    "outputs": [],
#     367    "source": [
#     368     "@jit\n",
#     369     "def kinetic_energy_fn(\n",
#     370     "    mass_matrix_nn_params: FrozenDict, th: Array, th_d: Array\n",
#     371     ") -> Array:\n",
#     372     "    \"\"\"\n",
#     373     "    Compute the kinetic energy of the system using a learned neural-network-based mass matrix\n",
#     374     "    Args:\n",
#     375     "        mass_matrix_nn_params: parameters of the MassMatrixNN\n",
#     376     "        th: link angles of shape (2, ).\n",
#     377     "            We assume that the link angles are already normalized to the interval [-pi, pi].\n",
#     378     "        th_d: link angular velocities of double pendulum of shape (2, )\n",
#     379     "    Returns:\n",
#     380     "        T: kinetic energy of shape ( )\n",
#     381     "    \"\"\"\n",
#     382     "    # evaluate mass matrix at current system state\n",
#     383     "    M = MassMatrixNN().apply({\"params\": mass_matrix_nn_params}, th)\n",
#     384     "\n",
#     385     "    # compute kinetic energy\n",
#     386     "    T = jnp.array(0)\n",
#     387     "    T = jnp.transpose(th_d) @ M @ th_d/2\n",
#     388     "    print(f\"T:{T}\")\n",
#     389     "\n",
#     390     "    return T"
#     391    ]
#     392   },
#     393   {
#     394    "cell_type": "code",
#     395    "execution_count": 22,
#     396    "id": "09e7875a",
#     397    "metadata": {
#     398     "deletable": false,
#     399     "nbgrader": {
#     400      "cell_type": "code",
#     401      "checksum": "8f840f66b12a2893fba9f4374d259091",
#     402      "grade": false,
#     403      "grade_id": "cell-6a3a2cc1abe3951d",
#     404      "locked": false,
#     405      "schema_version": 3,
#     406      "solution": true,
#     407      "task": false
#     408     }
#     409    },
#     410    "outputs": [],
#     411    "source": [
#     412     "@jit\n",
#     413     "def potential_energy_fn(potential_energy_nn_params: FrozenDict, th: Array) -> Array:\n",
#     414     "    \"\"\"\n",
#     415     "    Compute the potential energy of the system using the `PotentialEnergyNN` neural network\n",
#     416     "    Args:\n",
#     417     "        potential_energy_nn_params: parameters of the PotentialEnergyNN\n",
#     418     "        th: link angles of shape (2, ).\n",
#     419     "            We assume that the link angles are already normalized to the interval [-pi, pi].\n",
#     420     "    Returns:\n",
#     421     "        U: potential energy of shape ( )\n",
#     422     "    \"\"\"\n",
#     423     "    # evaluate the `PotentialEnergyNN` at current system state\n",
#     424     "    U = jnp.array(0)\n",
#     425     "    U = MassMatrixNN().apply({\"params\": potential_energy_nn_params}, th)\n",
#     426     "    print(f\"U:{U}\")\n",
#     427     "    return U"
#     428    ]
#     429   },
#     430   {
#     431    "cell_type": "code",
#     432    "execution_count": 23,
#     433    "id": "6126ac5a",
#     434    "metadata": {
#     435     "deletable": false,
#     436     "nbgrader": {
#     437      "cell_type": "code",
#     438      "checksum": "ab769f9deaa904988e2c52529788f3d4",
#     439      "grade": false,
#     440      "grade_id": "cell-216db944065f69db",
#     441      "locked": false,
#     442      "schema_version": 3,
#     443      "solution": true,
#     444      "task": false
#     445     }
#     446    },
#     447    "outputs": [],
#     448    "source": [
#     449     "@jit\n",
#     450     "def lagrangian_fn(\n",
#     451     "    mass_matrix_nn_params: FrozenDict,\n",
#     452     "    potential_energy_nn_params: FrozenDict,\n",
#     453     "    th: Array,\n",
#     454     "    th_d: Array,\n",
#     455     ") -> Array:\n",
#     456     "    \"\"\"\n",
#     457     "    Compute the Lagrangian of the system using a learned neural-network-based mass matrix and potential energy\n",
#     458     "    Args:\n",
#     459     "        mass_matrix_nn_params: parameters of the MassMatrixNN\n",
#     460     "        potential_energy_nn_params: parameters of the PotentialEnergyNN\n",
#     461     "        th: link angles of shape (2, ).\n",
#     462     "            We assume that the link angles are already normalized to the interval [-pi, pi].\n",
#     463     "        th_d: link angular velocities of double pendulum of shape (2, )\n",
#     464     "    Returns:\n",
#     465     "        L: Lagrangian of shape ( )\n",
#     466     "    \"\"\"\n",
#     467     "    # Compute the Lagrangian\n",
#     468     "    L = jnp.array(0)\n",
#     469     "    T = kinetic_energy_fn(mass_matrix_nn_params, th, th_d)\n",
#     470     "    U = potential_energy_fn(potential_energy_nn_params, th)\n",
#     471     "    L = T - U\n",
#     472     "    print(L)\n",
#     473     "    return L"
#     474    ]
#     475   },
#     476   {
#     477    "cell_type": "code",
#     478    "execution_count": 24,
#     479    "id": "6b4ced74",
#     480    "metadata": {
#     481     "deletable": false,
#     482     "nbgrader": {
#     483      "cell_type": "code",
#     484      "checksum": "b22c3a070c869cbf8d1e0448f0c3b4d7",
#     485      "grade": false,
#     486      "grade_id": "cell-82a33f0bd7f4ddcc",
#     487      "locked": false,
#     488      "schema_version": 3,
#     489      "solution": true,
#     490      "task": false
#     491     }
#     492    },
#     493    "outputs": [],
#     494    "source": [
#     495     "@jit\n",
#     496     "def dynamical_matrices(\n",
#     497     "    mass_matrix_nn_params: FrozenDict,\n",
#     498     "    potential_energy_nn_params: FrozenDict,\n",
#     499     "    th: Array,\n",
#     500     "    th_d: Array,\n",
#     501     ") -> Tuple[Array, Array, Array]:\n",
#     502     "    \"\"\"\n",
#     503     "    Compute the dynamical matrices of the system using a learned neural-network-based\n",
#     504     "    mass matrix and potential energy\n",
#     505     "    The resulting Equations of Motion (EoM) are given by:\n",
#     506     "        M @ th_dd + C @ th_d + G = tau\n",
#     507     "    where tau are the external torques applied on the links.\n",
#     508     "\n",
#     509     "    Args:\n",
#     510     "        mass_matrix_nn_params: parameters of the MassMatrixNN\n",
#     511     "        potential_energy_nn_params: parameters of the PotentialEnergyNN\n",
#     512     "        th: link angles of double pendulum of shape (2, )\n",
#     513     "        th_d: link angular velocities of double pendulum of shape (2, )\n",
#     514     "\n",
#     515     "    Returns:\n",
#     516     "        M: mass matrix of shape (2, 2)\n",
#     517     "        C: coriolis and centrifugal matrix of shape (2, 2)\n",
#     518     "        G: gravity matrix of shape (2, )\n",
#     519     "    \"\"\"\n",
#     520     "    # the neural network needs to be robust to the redundancy of th = th + n * 2*pi\n",
#     521     "    # therefore, we first project the given link angles onto the interval [-pi, pi]\n",
#     522     "    # Hint: use the `jax_double_pendulum.utils.normalize_link_angles` function.\n",
#     523     "    # Hint: use `jax.grad` or `jax.value_and_grad` for the 1st-order partial derivatives\n",
#     524     "    # Hint: use the `jax.hessian` function for computing the 2nd-order partial derivatives.\n",
#     525     "    # YOUR CODE HERE\n",
#     526     "    raise NotImplementedError()\n",
#     527     "\n",
#     528     "    # Compute the dynamical matrices by taking the appropiate partial derivatives of the Lagrangian\n",
#     529     "    M, C, G = jnp.zeros((2, 2)), jnp.zeros((2, 2)), jnp.zeros((2,))\n",
#     530     "    # YOUR CODE HERE\n",
#     531     "    raise NotImplementedError()\n",
#     532     "\n",
#     533     "    return M, C, G"
#     534    ]
#     535   },
#     536   {
#     537    "cell_type": "code",
#     538    "execution_count": 25,
#     539    "id": "05b32d77",
#     540    "metadata": {
#     541     "deletable": false,
#     542     "nbgrader": {
#     543      "cell_type": "code",
#     544      "checksum": "ecd943627176a0dd230ad89a1481233c",
#     545      "grade": false,
#     546      "grade_id": "cell-2538b9eeb0fe06f9",
#     547      "locked": false,
#     548      "schema_version": 3,
#     549      "solution": true,
#     550      "task": false
#     551     }
#     552    },
#     553    "outputs": [],
#     554    "source": [
#     555     "@jit\n",
#     556     "def continuous_forward_dynamics(\n",
#     557     "    mass_matrix_nn_params: FrozenDict,\n",
#     558     "    potential_energy_nn_params: FrozenDict,\n",
#     559     "    th: Array,\n",
#     560     "    th_d: Array,\n",
#     561     "    tau: Array = jnp.zeros((2,)),\n",
#     562     ") -> Array:\n",
#     563     "    \"\"\"\n",
#     564     "    Compute the continuous forward dynamics of the system using a learned neural-network-based\n",
#     565     "    mass matrix and potential energy\n",
#     566     "    Args:\n",
#     567     "        mass_matrix_nn_params: parameters of the MassMatrixNN\n",
#     568     "        potential_energy_nn_params: parameters of the PotentialEnergyNN\n",
#     569     "        th: link angles of double pendulum of shape (2, )\n",
#     570     "        th_d: link angular velocities of double pendulum of shape (2, )\n",
#     571     "        tau: link torques of double pendulum of shape (2, )\n",
#     572     "    Returns:\n",
#     573     "        th_dd: link angular accelerations of double pendulum of shape (2, )\n",
#     574     "    \"\"\"\n",
#     575     "    # Compute the angular acceleration of the links\n",
#     576     "    th_dd = jnp.zeros((2,))\n",
#     577     "    # YOUR CODE HERE\n",
#     578     "    raise NotImplementedError()\n",
#     579     "\n",
#     580     "    return th_dd"
#     581    ]
#     582   },
#     583   {
#     584    "cell_type": "code",
#     585    "execution_count": 26,
#     586    "id": "c6819b64",
#     587    "metadata": {
#     588     "deletable": false,
#     589     "nbgrader": {
#     590      "cell_type": "code",
#     591      "checksum": "312ded045a580c4cf427731da76b4d9a",
#     592      "grade": false,
#     593      "grade_id": "cell-04d5fab5a1e9a1e6",
#     594      "locked": false,
#     595      "schema_version": 3,
#     596      "solution": true,
#     597      "task": false
#     598     }
#     599    },
#     600    "outputs": [],
#     601    "source": [
#     602     "def continuous_state_space_dynamics(\n",
#     603     "    mass_matrix_nn_params: FrozenDict,\n",
#     604     "    potential_energy_nn_params: FrozenDict,\n",
#     605     "    x: Array,\n",
#     606     "    tau: Array,\n",
#     607     ") -> Tuple[Array, Array]:\n",
#     608     "    \"\"\"\n",
#     609     "    Compute the continuous forward dynamics of the system in state-space representation\n",
#     610     "    using the Lagrangian neural network\n",
#     611     "    Args:\n",
#     612     "        mass_matrix_nn_params: parameters of the MassMatrixNN\n",
#     613     "        potential_energy_nn_params: parameters of the PotentialEnergyNN\n",
#     614     "        x: system state of shape (4, ) consisting of the link angles and velocities\n",
#     615     "        tau: link torques of shape (2, )\n",
#     616     "    Returns:\n",
#     617     "        dx_dt: time derivative of the system state of shape (4, )\n",
#     618     "        y: system output of shape (2, ) consisting of the link angles\n",
#     619     "    \"\"\"\n",
#     620     "    # YOUR CODE HERE\n",
#     621     "    raise NotImplementedError()\n",
#     622     "\n",
#     623     "    return dx_dt, y"
#     624    ]
#     625   },
#     626   {
#     627    "cell_type": "code",
#     628    "execution_count": 27,
#     629    "id": "92563f5d",
#     630    "metadata": {
#     631     "deletable": false,
#     632     "nbgrader": {
#     633      "cell_type": "code",
#     634      "checksum": "28ce736ac34b83475181f56403d4b0c4",
#     635      "grade": false,
#     636      "grade_id": "cell-9290e00886679359",
#     637      "locked": false,
#     638      "schema_version": 3,
#     639      "solution": true,
#     640      "task": false
#     641     }
#     642    },
#     643    "outputs": [],
#     644    "source": [
#     645     "@jit\n",
#     646     "def discrete_forward_dynamics(\n",
#     647     "    mass_matrix_nn_params: FrozenDict,\n",
#     648     "    potential_energy_nn_params: FrozenDict,\n",
#     649     "    dt: Array,\n",
#     650     "    th_curr: Array,\n",
#     651     "    th_d_curr: Array,\n",
#     652     "    tau: Array = jnp.zeros((2,)),\n",
#     653     ") -> Tuple[Array, Array, Array]:\n",
#     654     "    \"\"\"\n",
#     655     "    Compute the discrete forward dynamics of the system using a learned neural-network-based\n",
#     656     "    mass matrix and potential energy\n",
#     657     "    Args:\n",
#     658     "        mass_matrix_nn_params: parameters of the MassMatrixNN\n",
#     659     "        potential_energy_nn_params: parameters of the PotentialEnergyNN\n",
#     660     "        dt: time step between the current and the next state [s] of shape ( )\n",
#     661     "        th_curr: current link angles of double pendulum of shape (2, )\n",
#     662     "        th_d_curr: current link angular velocities of double pendulum of shape (2, )\n",
#     663     "        tau: link torques of double pendulum of shape (2, )\n",
#     664     "    Returns:\n",
#     665     "        th_next: link angles at the next time step of double pendulum of shape (2, )\n",
#     666     "        th_d_next: link angular velocities at the next time step of double pendulum of shape (2, )\n",
#     667     "        th_dd: link angular accelerations between current and next time step of double pendulum of shape (2, )\n",
#     668     "    \"\"\"\n",
#     669     "    # YOUR CODE HERE\n",
#     670     "    raise NotImplementedError()\n",
#     671     "\n",
#     672     "    return th_next, th_d_next, th_dd"
#     673    ]
#     674   },
#     675   {
#     676    "cell_type": "code",
#     677    "execution_count": null,
#     678    "id": "7cdbdacd",
#     679    "metadata": {},
#     680    "outputs": [],
#     681    "source": []
#     682   }
#     683  ],
#     684  "metadata": {
#     685   "kernelspec": {
#     686    "display_name": "Python 3 (ipykernel)",
#     687    "language": "python",
#     688    "name": "python3"
#     689   },
#     690   "language_info": {
#     691    "codemirror_mode": {
#     692     "name": "ipython",
#     693     "version": 3
#     694    },
#     695    "file_extension": ".py",
#     696    "mimetype": "text/x-python",
#     697    "name": "python",
#     698    "nbconvert_exporter": "python",
#     699    "pygments_lexer": "ipython3",
#     700    "version": "3.11.8"
#     701   }
#     702  },
#     703  "nbformat": 4,
#     704  "nbformat_minor": 5
#     705 }
#
#     [... skipping hidden 12 frame]
#
# File c:\Users\thoma\OneDrive - Delft University of Technology\Documenten\UNI\Intelligent Control\ics-pa-sv\assignment\problem_2\lnn.ipynb:236, in potential_energy_fn(potential_energy_nn_params, th)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "id": "ac408b5e",
#       6    "metadata": {
#       7     "deletable": false,
#       8     "editable": false,
#       9     "nbgrader": {
#      10      "cell_type": "markdown",
#      11      "checksum": "7619294def77410a539e618e2428f0d5",
#      12      "grade": false,
#      13      "grade_id": "cell-b00828259c8e42e8",
#      14      "locked": true,
#      15      "schema_version": 3,
#      16      "solution": false,
#      17      "task": false
#      18     }
#      19    },
#      20    "source": [
#      21     "# RO47019: Intelligent Control Systems Practical Assignment\n",
#      22     "* Period: 2023-2024, Q3\n",
#      23     "* Course homepage: https://brightspace.tudelft.nl/d2l/home/500969\n",
#      24     "* Instructor: Cosimo Della Santina (C.DellaSantina@tudelft.nl)\n",
#      25     "* Teaching assistant: Maria de Neves de Fonseca (M.deNevesdeFonseca-1@student.tudelft.nl)\n",
#      26     "* (c) TU Delft, 2024\n",
#      27     "\n",
#      28     "Make sure you fill in any place that says `YOUR CODE HERE` or `YOUR ANSWER HERE`. Remove `raise NotImplementedError()` afterwards. Moreover, if you see an empty cell, please DO NOT delete it, instead run that cell as you would run all other cells. Please fill in your name(s) and other required details below:"
#      29    ]
#      30   },
#      31   {
#      32    "cell_type": "code",
#      33    "execution_count": 15,
#      34    "id": "4f9e220c",
#      35    "metadata": {},
#      36    "outputs": [],
#      37    "source": [
#      38     "# Please fill in your names, student numbers, netID, and emails below.\n",
#      39     "STUDENT_1_NAME = \"Thomas Evers\"\n",
#      40     "STUDENT_1_STUDENT_NUMBER = \"5310121\"\n",
#      41     "STUDENT_1_NETID = \"thomasevers\"\n",
#      42     "STUDENT_1_EMAIL = \"t.evers-2@student.tudelft.nl\""
#      43    ]
#      44   },
#      45   {
#      46    "cell_type": "code",
#      47    "execution_count": 16,
#      48    "id": "8ba32571",
#      49    "metadata": {
#      50     "deletable": false,
#      51     "editable": false,
#      52     "nbgrader": {
#      53      "cell_type": "code",
#      54      "checksum": "042927213b84aa368aa3ea72caa4cb60",
#      55      "grade": true,
#      56      "grade_id": "cell-9f148ec62e0de49c",
#      57      "locked": true,
#      58      "points": 0,
#      59      "schema_version": 3,
#      60      "solution": false,
#      61      "task": false
#      62     }
#      63    },
#      64    "outputs": [],
#      65    "source": [
#      66     "# Note: this block is a check that you have filled in the above information.\n",
#      67     "# It will throw an AssertionError until all fields are filled\n",
#      68     "assert STUDENT_1_NAME != \"\"\n",
#      69     "assert STUDENT_1_STUDENT_NUMBER != \"\"\n",
#      70     "assert STUDENT_1_NETID != \"\"\n",
#      71     "assert STUDENT_1_EMAIL != \"\""
#      72    ]
#      73   },
#      74   {
#      75    "cell_type": "markdown",
#      76    "id": "af317a94",
#      77    "metadata": {
#      78     "deletable": false,
#      79     "editable": false,
#      80     "nbgrader": {
#      81      "cell_type": "markdown",
#      82      "checksum": "95c5b11f9ac3896252d342cabb38d867",
#      83      "grade": false,
#      84      "grade_id": "cell-4ea391677951116c",
#      85      "locked": true,
#      86      "schema_version": 3,
#      87      "solution": false,
#      88      "task": false
#      89     }
#      90    },
#      91    "source": [
#      92     "### General announcements\n",
#      93     "\n",
#      94     "* Do *not* share your solutions (also after the course is finished), and do *not* copy solutions from others. By submitting your solutions, you claim that you alone are responsible for this code.\n",
#      95     "\n",
#      96     "* Do *not* email questions directly, since we want to provide everybody with the same information and avoid repeating the same answers. Instead, please post your questions regarding this assignment in the correct support forum on Brightspace, this way everybody can benefit from the response. If you do have a particular question that you want to ask directly, please use the scheduled Q&A hours to ask the TA.\n",
#      97     "\n",
#      98     "* There is a strict deadline for each assignment. Students are responsible to ensure that they have uploaded their work in time. So, please double check that your upload succeeded to the Brightspace and avoid any late penalties.\n",
#      99     "\n",
#     100     "* This [Jupyter notebook](https://jupyter.org/) uses `nbgrader` to help us with automated tests. `nbgrader` will make various cells in this notebook \"uneditable\" or \"unremovable\" and gives them a special id in the cell metadata. This way, when we run our checks, the system will check the existence of the cell ids and verify the number of points and which checks must be run. While there are ways that you can edit the metadata and work around the restrictions to delete or modify these special cells, you should not do that since then our nbgrader backend will not be able to parse your notebook and give you points for the assignment. You are free to add additional cells, but if you find a cell that you cannot modify or remove, please know that this is on purpose.\n",
#     101     "\n",
#     102     "* This notebook will have in various places a line that throws a `NotImplementedError` exception. These are locations where the assignment requires you to adapt the code! These lines are just there as a reminder for you that you have not yet adapted that particular piece of code, especially when you execute all the cells. Once your solution code replaced these lines, it should accordingly *not* throw any exceptions anymore.\n",
#     103     "\n",
#     104     "Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\\rightarrow$Run All)."
#     105    ]
#     106   },
#     107   {
#     108    "cell_type": "code",
#     109    "execution_count": 17,
#     110    "id": "3c956945",
#     111    "metadata": {},
#     112    "outputs": [],
#     113    "source": [
#     114     "import sys\n",
#     115     "sys.path.append(\"C:/Users/thoma/OneDrive - Delft University of Technology/Documenten/UNI/Intelligent Control/ics-pa-sv\")"
#     116    ]
#     117   },
#     118   {
#     119    "cell_type": "markdown",
#     120    "id": "387d2c60",
#     121    "metadata": {
#     122     "deletable": false,
#     123     "editable": false,
#     124     "nbgrader": {
#     125      "cell_type": "markdown",
#     126      "checksum": "7a3b42b2fb38c185d4bbc65fbe1c7f8d",
#     127      "grade": false,
#     128      "grade_id": "cell-ed88010142fb94bb",
#     129      "locked": true,
#     130      "schema_version": 3,
#     131      "solution": false,
#     132      "task": false
#     133     }
#     134    },
#     135    "source": [
#     136     "# Lagrangian Neural Network (LNN)\n",
#     137     "\n",
#     138     "**Author:** Maximilian Stölzle (M.W.Stolzle@tudelft.nl)\n",
#     139     "\n",
#     140     "This notebook will contain functions for implementing a Lagrangian neural network. Please follow the notebook `task_2c-2_lnn_implementation.ipynb`, which guides you through these implementations."
#     141    ]
#     142   },
#     143   {
#     144    "cell_type": "code",
#     145    "execution_count": 18,
#     146    "id": "c5a29eaa",
#     147    "metadata": {
#     148     "deletable": false,
#     149     "editable": false,
#     150     "nbgrader": {
#     151      "cell_type": "code",
#     152      "checksum": "2d6635d3a20ea7ea4643049a39727636",
#     153      "grade": false,
#     154      "grade_id": "cell-6d73deac900e51cb",
#     155      "locked": true,
#     156      "schema_version": 3,
#     157      "solution": false,
#     158      "task": false
#     159     }
#     160    },
#     161    "outputs": [],
#     162    "source": [
#     163     "from flax import linen as nn\n",
#     164     "from flax.core import FrozenDict\n",
#     165     "from functools import partial\n",
#     166     "from jax import config as jax_config\n",
#     167     "\n",
#     168     "jax_config.update(\"jax_platform_name\", \"cpu\")  # set default device to 'cpu'\n",
#     169     "jax_config.update(\"jax_enable_x64\", True)  # double precision\n",
#     170     "import jax\n",
#     171     "from jax import Array, jit, debug\n",
#     172     "import jax.numpy as jnp\n",
#     173     "import numpy as np\n",
#     174     "from typing import Dict, Tuple\n",
#     175     "\n",
#     176     "from jax_double_pendulum.integrators import rk4_step\n",
#     177     "from jax_double_pendulum.utils import normalize_link_angles"
#     178    ]
#     179   },
#     180   {
#     181    "cell_type": "code",
#     182    "execution_count": 19,
#     183    "id": "f23c573c",
#     184    "metadata": {
#     185     "deletable": false,
#     186     "nbgrader": {
#     187      "cell_type": "code",
#     188      "checksum": "dfa37c5c2491b941a85ee5f38abf8550",
#     189      "grade": false,
#     190      "grade_id": "cell-90677efa4e583357",
#     191      "locked": false,
#     192      "schema_version": 3,
#     193      "solution": true,
#     194      "task": false
#     195     }
#     196    },
#     197    "outputs": [],
#     198    "source": [
#     199     "class MassMatrixNN(nn.Module):\n",
#     200     "    \"\"\"\n",
#     201     "    Neural network to approximate the mass matrix.\n",
#     202     "    \"\"\"\n",
#     203     "\n",
#     204     "    num_hidden: int = 32  # Number of hidden units per intermediate layer\n",
#     205     "\n",
#     206     "    diagonal_shift = 0.001  # shifting the diagonal before activation function\n",
#     207     "    diagonal_eps = 0.002  # small value added to the resulting diagonal\n",
#     208     "\n",
#     209     "    @nn.compact\n",
#     210     "    def __call__(self, th: Array) -> Array:\n",
#     211     "        \"\"\"\n",
#     212     "        Evaluate the mass matrix for the current neural network parameters\n",
#     213     "        Args:\n",
#     214     "            th: link angles of shape (2, ).\n",
#     215     "                We assume that the link angles are already normalized to the interval [-pi, pi].\n",
#     216     "        Returns:\n",
#     217     "            M: mass matrix of shape (2, 2)\n",
#     218     "        \"\"\"\n",
#     219     "        num_dof = th.shape[-1]  # Degrees of Freedom of the robot\n",
#     220     "        num_nn_outputs = int((num_dof**2 + num_dof) / 2)\n",
#     221     "\n",
#     222     "        # implement the neural network layers\n",
#     223     "        # use nn.Dense and nn.softplus layers\n",
#     224     "        # the output of the last layer needs to be saved in the variable `m`\n",
#     225     "        # the elements of the triangular matrix are the outputs of the network\n",
#     226     "        m = jnp.zeros((num_nn_outputs,))\n",
#     227     "        full_layer1 = nn.Dense(self.num_hidden)\n",
#     228     "        full_layer2 = nn.Dense(self.num_hidden)\n",
#     229     "        full_layer3 = nn.Dense(self.num_hidden)\n",
#     230     "        full_layer4 = nn.Dense(self.num_hidden)\n",
#     231     "        output_layer= nn.Dense(features=num_nn_outputs)\n",
#     232     "        \n",
#     233     "        x = full_layer1(th)\n",
#     234     "        x = nn.activation.softplus(x)\n",
#     235     "        x = full_layer2(x)\n",
# --> 236     "        x = nn.activation.softplus(x)\n",
#     237     "        x = full_layer3(x)\n",
#     238     "        x = nn.activation.softplus(x)\n",
#     239     "        x = full_layer4(x)\n",
#     240     "        x = nn.activation.softplus(x)\n",
#     241     "        m = output_layer(x)\n",
#     242     "\n",
#     243     "\n",
#     244     "        # split-off the first num_dof as the diagonal entries\n",
#     245     "        l_diagonal, l_off_diagonal = jnp.split(\n",
#     246     "            m,\n",
#     247     "            np.array(\n",
#     248     "                [\n",
#     249     "                    num_dof,\n",
#     250     "                ]\n",
#     251     "            ),\n",
#     252     "            axis=-1,\n",
#     253     "        )\n",
#     254     "\n",
#     255     "        # ensure positive diagonal\n",
#     256     "        # first, add `self.diagonal_shift` to the diagonal\n",
#     257     "        l_diagonal = l_diagonal + self.diagonal_shift\n",
#     258     "        \n",
#     259     "        # then, apply softplus\n",
#     260     "        l_diagonal = nn.softplus(l_diagonal)\n",
#     261     "        \n",
#     262     "        # finally, add `self.diagonal_eps` to the diagonal\n",
#     263     "        l_diagonal = l_diagonal + self.diagonal_eps\n",
#     264     "        \n",
#     265     "\n",
#     266     "        # Calculate the indices of the diagonal elements of L:\n",
#     267     "        indices_diag = np.arange(num_dof, dtype=int) + 1\n",
#     268     "        indices_diag = (indices_diag * (indices_diag + 1) / 2 - 1).astype(int)  # [0, 2]\n",
#     269     "        # Calculate the indices of the off-diagonal elements of L:\n",
#     270     "        indices_off_diag = np.setdiff1d(np.arange(num_nn_outputs), indices_diag)  # [1]\n",
#     271     "        # Indexing for concatenation of l_diagonal and l_off_diagonal\n",
#     272     "        indices_nn_output = np.hstack((indices_diag, indices_off_diag))  # [0, 2, 1]\n",
#     273     "\n",
#     274     "        # vector of lower triangular matrix (i.e. flattened lower triangular matrix)\n",
#     275     "        vec_tril = jnp.concatenate([l_diagonal, l_off_diagonal], axis=-1)[\n",
#     276     "            ..., indices_nn_output\n",
#     277     "        ]\n",
#     278     "\n",
#     279     "        # construct empty triangular matrix\n",
#     280     "        tril_mat = jnp.zeros((num_dof, num_dof))\n",
#     281     "        # (i, j) indices of lower triangular matrix\n",
#     282     "        indices_tril = np.tril_indices(num_dof)  # (array([0, 1, 1]), array([0, 0, 1]))\n",
#     283     "        # populate triangular matrix from vector\n",
#     284     "        tril_mat = tril_mat.at[indices_tril].set(vec_tril[:])\n",
#     285     "\n",
#     286     "        # construct mass matrix from triangular matrix\n",
#     287     "        M = tril_mat @ tril_mat.transpose()\n",
#     288     "        assert M.shape == (2, 2)\n",
#     289     "\n",
#     290     "        return M"
#     291    ]
#     292   },
#     293   {
#     294    "cell_type": "code",
#     295    "execution_count": 20,
#     296    "id": "a6974402",
#     297    "metadata": {
#     298     "deletable": false,
#     299     "nbgrader": {
#     300      "cell_type": "code",
#     301      "checksum": "94a5da4d394415a8d6c56a8b18a35386",
#     302      "grade": false,
#     303      "grade_id": "cell-e2583bbbc2ae1715",
#     304      "locked": false,
#     305      "schema_version": 3,
#     306      "solution": true,
#     307      "task": false
#     308     }
#     309    },
#     310    "outputs": [],
#     311    "source": [
#     312     "class PotentialEnergyNN(nn.Module):\n",
#     313     "    \"\"\"\n",
#     314     "    Neural network to approximate the potential energy.\n",
#     315     "    \"\"\"\n",
#     316     "\n",
#     317     "    num_hidden: int = 32  # Number of hidden units per intermediate layer\n",
#     318     "\n",
#     319     "    @nn.compact\n",
#     320     "    def __call__(self, th: Array) -> Array:\n",
# ...
#     370     "    mass_matrix_nn_params: FrozenDict, th: Array, th_d: Array\n",
#     371     ") -> Array:\n",
#     372     "    \"\"\"\n",
#     373     "    Compute the kinetic energy of the system using a learned neural-network-based mass matrix\n",
#     374     "    Args:\n",
#     375     "        mass_matrix_nn_params: parameters of the MassMatrixNN\n",
#     376     "        th: link angles of shape (2, ).\n",
#     377     "            We assume that the link angles are already normalized to the interval [-pi, pi].\n",
#     378     "        th_d: link angular velocities of double pendulum of shape (2, )\n",
#     379     "    Returns:\n",
#     380     "        T: kinetic energy of shape ( )\n",
#     381     "    \"\"\"\n",
#     382     "    # evaluate mass matrix at current system state\n",
#     383     "    M = MassMatrixNN().apply({\"params\": mass_matrix_nn_params}, th)\n",
#     384     "\n",
#     385     "    # compute kinetic energy\n",
#     386     "    T = jnp.array(0)\n",
#     387     "    T = jnp.transpose(th_d) @ M @ th_d/2\n",
#     388     "    print(f\"T:{T}\")\n",
#     389     "\n",
#     390     "    return T"
#     391    ]
#     392   },
#     393   {
#     394    "cell_type": "code",
#     395    "execution_count": 22,
#     396    "id": "09e7875a",
#     397    "metadata": {
#     398     "deletable": false,
#     399     "nbgrader": {
#     400      "cell_type": "code",
#     401      "checksum": "8f840f66b12a2893fba9f4374d259091",
#     402      "grade": false,
#     403      "grade_id": "cell-6a3a2cc1abe3951d",
#     404      "locked": false,
#     405      "schema_version": 3,
#     406      "solution": true,
#     407      "task": false
#     408     }
#     409    },
#     410    "outputs": [],
#     411    "source": [
#     412     "@jit\n",
#     413     "def potential_energy_fn(potential_energy_nn_params: FrozenDict, th: Array) -> Array:\n",
#     414     "    \"\"\"\n",
#     415     "    Compute the potential energy of the system using the `PotentialEnergyNN` neural network\n",
#     416     "    Args:\n",
#     417     "        potential_energy_nn_params: parameters of the PotentialEnergyNN\n",
#     418     "        th: link angles of shape (2, ).\n",
#     419     "            We assume that the link angles are already normalized to the interval [-pi, pi].\n",
#     420     "    Returns:\n",
#     421     "        U: potential energy of shape ( )\n",
#     422     "    \"\"\"\n",
#     423     "    # evaluate the `PotentialEnergyNN` at current system state\n",
#     424     "    U = jnp.array(0)\n",
#     425     "    U = MassMatrixNN().apply({\"params\": potential_energy_nn_params}, th)\n",
#     426     "    print(f\"U:{U}\")\n",
#     427     "    return U"
#     428    ]
#     429   },
#     430   {
#     431    "cell_type": "code",
#     432    "execution_count": 23,
#     433    "id": "6126ac5a",
#     434    "metadata": {
#     435     "deletable": false,
#     436     "nbgrader": {
#     437      "cell_type": "code",
#     438      "checksum": "ab769f9deaa904988e2c52529788f3d4",
#     439      "grade": false,
#     440      "grade_id": "cell-216db944065f69db",
#     441      "locked": false,
#     442      "schema_version": 3,
#     443      "solution": true,
#     444      "task": false
#     445     }
#     446    },
#     447    "outputs": [],
#     448    "source": [
#     449     "@jit\n",
#     450     "def lagrangian_fn(\n",
#     451     "    mass_matrix_nn_params: FrozenDict,\n",
#     452     "    potential_energy_nn_params: FrozenDict,\n",
#     453     "    th: Array,\n",
#     454     "    th_d: Array,\n",
#     455     ") -> Array:\n",
#     456     "    \"\"\"\n",
#     457     "    Compute the Lagrangian of the system using a learned neural-network-based mass matrix and potential energy\n",
#     458     "    Args:\n",
#     459     "        mass_matrix_nn_params: parameters of the MassMatrixNN\n",
#     460     "        potential_energy_nn_params: parameters of the PotentialEnergyNN\n",
#     461     "        th: link angles of shape (2, ).\n",
#     462     "            We assume that the link angles are already normalized to the interval [-pi, pi].\n",
#     463     "        th_d: link angular velocities of double pendulum of shape (2, )\n",
#     464     "    Returns:\n",
#     465     "        L: Lagrangian of shape ( )\n",
#     466     "    \"\"\"\n",
#     467     "    # Compute the Lagrangian\n",
#     468     "    L = jnp.array(0)\n",
#     469     "    T = kinetic_energy_fn(mass_matrix_nn_params, th, th_d)\n",
#     470     "    U = potential_energy_fn(potential_energy_nn_params, th)\n",
#     471     "    L = T - U\n",
#     472     "    print(L)\n",
#     473     "    return L"
#     474    ]
#     475   },
#     476   {
#     477    "cell_type": "code",
#     478    "execution_count": 24,
#     479    "id": "6b4ced74",
#     480    "metadata": {
#     481     "deletable": false,
#     482     "nbgrader": {
#     483      "cell_type": "code",
#     484      "checksum": "b22c3a070c869cbf8d1e0448f0c3b4d7",
#     485      "grade": false,
#     486      "grade_id": "cell-82a33f0bd7f4ddcc",
#     487      "locked": false,
#     488      "schema_version": 3,
#     489      "solution": true,
#     490      "task": false
#     491     }
#     492    },
#     493    "outputs": [],
#     494    "source": [
#     495     "@jit\n",
#     496     "def dynamical_matrices(\n",
#     497     "    mass_matrix_nn_params: FrozenDict,\n",
#     498     "    potential_energy_nn_params: FrozenDict,\n",
#     499     "    th: Array,\n",
#     500     "    th_d: Array,\n",
#     501     ") -> Tuple[Array, Array, Array]:\n",
#     502     "    \"\"\"\n",
#     503     "    Compute the dynamical matrices of the system using a learned neural-network-based\n",
#     504     "    mass matrix and potential energy\n",
#     505     "    The resulting Equations of Motion (EoM) are given by:\n",
#     506     "        M @ th_dd + C @ th_d + G = tau\n",
#     507     "    where tau are the external torques applied on the links.\n",
#     508     "\n",
#     509     "    Args:\n",
#     510     "        mass_matrix_nn_params: parameters of the MassMatrixNN\n",
#     511     "        potential_energy_nn_params: parameters of the PotentialEnergyNN\n",
#     512     "        th: link angles of double pendulum of shape (2, )\n",
#     513     "        th_d: link angular velocities of double pendulum of shape (2, )\n",
#     514     "\n",
#     515     "    Returns:\n",
#     516     "        M: mass matrix of shape (2, 2)\n",
#     517     "        C: coriolis and centrifugal matrix of shape (2, 2)\n",
#     518     "        G: gravity matrix of shape (2, )\n",
#     519     "    \"\"\"\n",
#     520     "    # the neural network needs to be robust to the redundancy of th = th + n * 2*pi\n",
#     521     "    # therefore, we first project the given link angles onto the interval [-pi, pi]\n",
#     522     "    # Hint: use the `jax_double_pendulum.utils.normalize_link_angles` function.\n",
#     523     "    # Hint: use `jax.grad` or `jax.value_and_grad` for the 1st-order partial derivatives\n",
#     524     "    # Hint: use the `jax.hessian` function for computing the 2nd-order partial derivatives.\n",
#     525     "    # YOUR CODE HERE\n",
#     526     "    raise NotImplementedError()\n",
#     527     "\n",
#     528     "    # Compute the dynamical matrices by taking the appropiate partial derivatives of the Lagrangian\n",
#     529     "    M, C, G = jnp.zeros((2, 2)), jnp.zeros((2, 2)), jnp.zeros((2,))\n",
#     530     "    # YOUR CODE HERE\n",
#     531     "    raise NotImplementedError()\n",
#     532     "\n",
#     533     "    return M, C, G"
#     534    ]
#     535   },
#     536   {
#     537    "cell_type": "code",
#     538    "execution_count": 25,
#     539    "id": "05b32d77",
#     540    "metadata": {
#     541     "deletable": false,
#     542     "nbgrader": {
#     543      "cell_type": "code",
#     544      "checksum": "ecd943627176a0dd230ad89a1481233c",
#     545      "grade": false,
#     546      "grade_id": "cell-2538b9eeb0fe06f9",
#     547      "locked": false,
#     548      "schema_version": 3,
#     549      "solution": true,
#     550      "task": false
#     551     }
#     552    },
#     553    "outputs": [],
#     554    "source": [
#     555     "@jit\n",
#     556     "def continuous_forward_dynamics(\n",
#     557     "    mass_matrix_nn_params: FrozenDict,\n",
#     558     "    potential_energy_nn_params: FrozenDict,\n",
#     559     "    th: Array,\n",
#     560     "    th_d: Array,\n",
#     561     "    tau: Array = jnp.zeros((2,)),\n",
#     562     ") -> Array:\n",
#     563     "    \"\"\"\n",
#     564     "    Compute the continuous forward dynamics of the system using a learned neural-network-based\n",
#     565     "    mass matrix and potential energy\n",
#     566     "    Args:\n",
#     567     "        mass_matrix_nn_params: parameters of the MassMatrixNN\n",
#     568     "        potential_energy_nn_params: parameters of the PotentialEnergyNN\n",
#     569     "        th: link angles of double pendulum of shape (2, )\n",
#     570     "        th_d: link angular velocities of double pendulum of shape (2, )\n",
#     571     "        tau: link torques of double pendulum of shape (2, )\n",
#     572     "    Returns:\n",
#     573     "        th_dd: link angular accelerations of double pendulum of shape (2, )\n",
#     574     "    \"\"\"\n",
#     575     "    # Compute the angular acceleration of the links\n",
#     576     "    th_dd = jnp.zeros((2,))\n",
#     577     "    # YOUR CODE HERE\n",
#     578     "    raise NotImplementedError()\n",
#     579     "\n",
#     580     "    return th_dd"
#     581    ]
#     582   },
#     583   {
#     584    "cell_type": "code",
#     585    "execution_count": 26,
#     586    "id": "c6819b64",
#     587    "metadata": {
#     588     "deletable": false,
#     589     "nbgrader": {
#     590      "cell_type": "code",
#     591      "checksum": "312ded045a580c4cf427731da76b4d9a",
#     592      "grade": false,
#     593      "grade_id": "cell-04d5fab5a1e9a1e6",
#     594      "locked": false,
#     595      "schema_version": 3,
#     596      "solution": true,
#     597      "task": false
#     598     }
#     599    },
#     600    "outputs": [],
#     601    "source": [
#     602     "def continuous_state_space_dynamics(\n",
#     603     "    mass_matrix_nn_params: FrozenDict,\n",
#     604     "    potential_energy_nn_params: FrozenDict,\n",
#     605     "    x: Array,\n",
#     606     "    tau: Array,\n",
#     607     ") -> Tuple[Array, Array]:\n",
#     608     "    \"\"\"\n",
#     609     "    Compute the continuous forward dynamics of the system in state-space representation\n",
#     610     "    using the Lagrangian neural network\n",
#     611     "    Args:\n",
#     612     "        mass_matrix_nn_params: parameters of the MassMatrixNN\n",
#     613     "        potential_energy_nn_params: parameters of the PotentialEnergyNN\n",
#     614     "        x: system state of shape (4, ) consisting of the link angles and velocities\n",
#     615     "        tau: link torques of shape (2, )\n",
#     616     "    Returns:\n",
#     617     "        dx_dt: time derivative of the system state of shape (4, )\n",
#     618     "        y: system output of shape (2, ) consisting of the link angles\n",
#     619     "    \"\"\"\n",
#     620     "    # YOUR CODE HERE\n",
#     621     "    raise NotImplementedError()\n",
#     622     "\n",
#     623     "    return dx_dt, y"
#     624    ]
#     625   },
#     626   {
#     627    "cell_type": "code",
#     628    "execution_count": 27,
#     629    "id": "92563f5d",
#     630    "metadata": {
#     631     "deletable": false,
#     632     "nbgrader": {
#     633      "cell_type": "code",
#     634      "checksum": "28ce736ac34b83475181f56403d4b0c4",
#     635      "grade": false,
#     636      "grade_id": "cell-9290e00886679359",
#     637      "locked": false,
#     638      "schema_version": 3,
#     639      "solution": true,
#     640      "task": false
#     641     }
#     642    },
#     643    "outputs": [],
#     644    "source": [
#     645     "@jit\n",
#     646     "def discrete_forward_dynamics(\n",
#     647     "    mass_matrix_nn_params: FrozenDict,\n",
#     648     "    potential_energy_nn_params: FrozenDict,\n",
#     649     "    dt: Array,\n",
#     650     "    th_curr: Array,\n",
#     651     "    th_d_curr: Array,\n",
#     652     "    tau: Array = jnp.zeros((2,)),\n",
#     653     ") -> Tuple[Array, Array, Array]:\n",
#     654     "    \"\"\"\n",
#     655     "    Compute the discrete forward dynamics of the system using a learned neural-network-based\n",
#     656     "    mass matrix and potential energy\n",
#     657     "    Args:\n",
#     658     "        mass_matrix_nn_params: parameters of the MassMatrixNN\n",
#     659     "        potential_energy_nn_params: parameters of the PotentialEnergyNN\n",
#     660     "        dt: time step between the current and the next state [s] of shape ( )\n",
#     661     "        th_curr: current link angles of double pendulum of shape (2, )\n",
#     662     "        th_d_curr: current link angular velocities of double pendulum of shape (2, )\n",
#     663     "        tau: link torques of double pendulum of shape (2, )\n",
#     664     "    Returns:\n",
#     665     "        th_next: link angles at the next time step of double pendulum of shape (2, )\n",
#     666     "        th_d_next: link angular velocities at the next time step of double pendulum of shape (2, )\n",
#     667     "        th_dd: link angular accelerations between current and next time step of double pendulum of shape (2, )\n",
#     668     "    \"\"\"\n",
#     669     "    # YOUR CODE HERE\n",
#     670     "    raise NotImplementedError()\n",
#     671     "\n",
#     672     "    return th_next, th_d_next, th_dd"
#     673    ]
#     674   },
#     675   {
#     676    "cell_type": "code",
#     677    "execution_count": null,
#     678    "id": "7cdbdacd",
#     679    "metadata": {},
#     680    "outputs": [],
#     681    "source": []
#     682   }
#     683  ],
#     684  "metadata": {
#     685   "kernelspec": {
#     686    "display_name": "Python 3 (ipykernel)",
#     687    "language": "python",
#     688    "name": "python3"
#     689   },
#     690   "language_info": {
#     691    "codemirror_mode": {
#     692     "name": "ipython",
#     693     "version": 3
#     694    },
#     695    "file_extension": ".py",
#     696    "mimetype": "text/x-python",
#     697    "name": "python",
#     698    "nbconvert_exporter": "python",
#     699    "pygments_lexer": "ipython3",
#     700    "version": "3.11.8"
#     701   }
#     702  },
#     703  "nbformat": 4,
#     704  "nbformat_minor": 5
#     705 }
#
#     [... skipping hidden 2 frame]
#
# File c:\Users\thoma\anaconda3\envs\ics\Lib\site-packages\flax\linen\linear.py:254, in Dense.__call__(self, inputs)
#     244 @compact
#     245 def __call__(self, inputs: Array) -> Array:
#     246   """Applies a linear transformation to the inputs along the last dimension.
#     247
#     248   Args:
#    (...)
#     252     The transformed input.
#     253   """
# --> 254   kernel = self.param(
#     255     'kernel',
#     256     self.kernel_init,
#     257     (jnp.shape(inputs)[-1], self.features),
#     258     self.param_dtype,
#     259   )
#     260   if self.use_bias:
#     261     bias = self.param(
#     262       'bias', self.bias_init, (self.features,), self.param_dtype
#     263     )
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\thoma\anaconda3\envs\ics\Lib\site-packages\flax\core\scope.py:960, in Scope.param(self, name, init_fn, unbox, *init_args)
#     955   for val, abs_val in zip(value_flat, abs_value_flat):
#     956     # NOTE: We could check dtype consistency here as well but it's
#     957     # usefuleness is less obvious. We might intentionally change the dtype
#     958     # for inference to a half float type for example.
#     959     if jnp.shape(val) != jnp.shape(abs_val):
# --> 960       raise errors.ScopeParamShapeError(
#     961         name, self.path_text, jnp.shape(abs_val), jnp.shape(val)
#     962       )
#     963 else:
#     964   if not self.is_mutable_collection('params'):
#
# ScopeParamShapeError: Initializer expected to generate shape (32, 1) but got shape (32, 3) instead for parameter "kernel" in "/Dense_4". (https://flax.readthedocs.io/en/latest/api_reference/flax.errors.html#flax.errors.ScopeParamShapeError)

# %% [markdown]
# ## Continuous forward dynamics (4p)
#
# Next, please take the various partial derivatives of the Lagrangian to compute the dynamical matrices (i.e. the components of the equations of motion) in the function `dynamical_matrices`
#
# \begin{equation}
#     M = \frac{\partial^2 \mathcal{L}}{\partial \dot{\theta}^2},
#     \qquad
#     C = \frac{\partial^2 \mathcal{L}}{\partial \theta \partial \dot{\theta}},
#     \qquad
#     G = - \frac{\partial \mathcal{L}}{\partial \theta}.
# \end{equation}
#
# Make sure that before you evaluate the Lagrangian, you normalize the link angles $\theta$ to the interval $[-\pi, \pi]$. If we were not to implement this normalization, we would (likely) get a different behaviour for $\theta = a$ or $\theta = a + 2 \: \pi$, which is not desired. This would also drastically increase the amount of training data we would require.
#
# Then, please compute the continuous forward dynamics (i.e. determining $\ddot{\theta}$ for a given state $(\theta, \dot{\theta})$ and input $\tau$) in the function `continuous_forward_dynamics`. For this implementation, you can take inspiration from the analytical solution in `jax_double_pendulum.dynamics.continuous_forward_dynamics`.

# %%
# DO NOT REMOVE OR MODIFY THIS CELL

# import dynamical_matrices from lnn.ipynb
from ipynb.fs.full.lnn import dynamical_matrices, continuous_forward_dynamics

_M, _C, _G = dynamical_matrices(
    _mass_matrix_nn_params,
    _potential_energy_nn_params,
    _th,
    _th_d,
)

_M_target = jnp.array([[0.54595144, -0.53372961], [-0.53372961, 0.97476694]])
_C_target = jnp.array([[0.25423738, 0.00539128], [-0.069986, 0.09831604]])
_G_target = jnp.array([-0.24982781, -0.21771264])

print("Computed M:\n", _M)

# the mass matrix estimated by the neural network should be the same as d2L_d2thd
if not jnp.allclose(_M_nn, _M, rtol=RTOL, atol=ATOL):
    warnings.warn(
        "The mass matrix computed from the Lagrangian needs to match the output of the neural network."
    )

print("Target M:\n", _M_target)
if not jnp.allclose(_M, _M_target, rtol=RTOL, atol=ATOL):
    warnings.warn("The computed mass matrix is not correct.")

print("Computed C:\n", _C)
print("Target C:\n", _C_target)
if not jnp.allclose(_C, _C_target, rtol=RTOL, atol=ATOL):
    warnings.warn("The computed coriolis matrix is not correct.")

print("Computed G:\n", _G)
print("Target G:\n", _G_target)
if not jnp.allclose(_G, _G_target, rtol=RTOL, atol=ATOL):
    warnings.warn("The computed gravity vector is not correct.")

# zero applied torque
_tau = jnp.ones((2,))

_th_dd = continuous_forward_dynamics(
    _mass_matrix_nn_params,
    _potential_energy_nn_params,
    _th,
    _th_d,
    _tau,
)

_th_dd_target = jnp.array([4.14726048, 3.42874464])

print("Computed th_dd:\n", _th_dd)
print("Target th_dd:\n", _th_dd_target)
if not jnp.allclose(_th_dd, _th_dd_target, rtol=RTOL, atol=ATOL):
    warnings.warn("The computed angular link acceleration is not correct.")

# %% [markdown]
# ## State-space dynamics (1p)
#
# Please implement dynamics in a nonlinear state-space representation into the function `continuous_state_space_dynamics`. The state-space representation needs to have the following structure
#
# \begin{equation}
#     \frac{\mathrm{d}x}{\mathrm{d}t} = f(x, \tau),\\
#     y = g(x, \tau),
# \end{equation}
#
# where $x \in \mathbb{R}^4$ is the state of the system. For implementing this function, you can take inspiration from `jax_double_pendulum.dynamics.continuous_state_space_dynamics`.
#
# Having the EoM in this structure will allow us in the next step to use standard methods such as [RK4](https://en.wikipedia.org/wiki/Runge–Kutta_methods) to integrate the ODE in time.

# %%
# DO NOT REMOVE OR MODIFY THIS CELL

# import continuous_state_space_dynamics from lnn.ipynb
from ipynb.fs.full.lnn import continuous_state_space_dynamics

# define a dummy state
_x = jnp.concatenate([_th, _th_d])

_dx_dt, _y = continuous_state_space_dynamics(
    _mass_matrix_nn_params,
    _potential_energy_nn_params,
    _x,
    _tau,
)

_dx_dt_target = jnp.array([3.14159265, 3.14159265, 4.14726048, 3.42874464])
_y_target = jnp.array([[0.0, 0.0]])

print("Computed dx_dt:\n", _dx_dt)
print("Target dx_dt:\n", _dx_dt_target)
if not jnp.allclose(_dx_dt, _dx_dt_target, rtol=RTOL, atol=ATOL):
    warnings.warn("The computed time derivative of the state is not correct.")

print("Computed y:", _y, "target y:", _y_target)
if not jnp.allclose(_y, _y_target, rtol=RTOL, atol=ATOL):
    warnings.warn("The computed system output is not correct.")

# %% [markdown]
# ## Discrete-time forward dynamics (1p)
#
# Now, we move on to implementing the discrete-time forward dynamics into `discrete_forward_dynamics`.
# Please use the `jax_double_pendulum.integrators.rk4_step` function to integrate the continuous state-space dynamics for one time-step of duration `dt`. The `rk4_step` expects as its first argument an `ode_fun`, which needs to conform to the following syntax: `rk4_step(x) -> dx_dt` (i.e. a mapping from the state $x$ to its time-derivative $\dot{x}$). For implementing this function, you can take inspiration from `jax_double_pendulum.dynamics.discrete_forward_dynamics`.

# %%
# DO NOT REMOVE OR MODIFY THIS CELL

# import discrete_forward_dynamics from lnn.ipynb
from ipynb.fs.full.lnn import discrete_forward_dynamics

_dt = 1e-2  # time-step [s]
_th_next, _th_d_next, _th_dd = discrete_forward_dynamics(
    _mass_matrix_nn_params,
    _potential_energy_nn_params,
    _dt,
    _th,
    _th_d,
    _tau,
)

_th_next_target = jnp.array([0.03162163, 0.0315865])
_th_d_next_target = jnp.array([3.18256705, 3.17561977])
_th_dd_target = jnp.array([4.14726048, 3.42874464])

print("Computed th_next:\n", _th_next)
print("Target th_next:\n", _th_next_target)
if not jnp.allclose(_th_next, _th_next_target, rtol=RTOL, atol=ATOL):
    warnings.warn("The computed next link angles are not correct.")

print("Computed th_d_next:\n", _th_d_next)
print("Target th_d_next:\n", _th_d_next_target)
if not jnp.allclose(_th_d_next, _th_d_next_target, rtol=RTOL, atol=ATOL):
    warnings.warn("The computed next angular link velocities are not correct.")

print("Computed th_d_next:\n", _th_dd)
print("Target th_d_next:\n", _th_dd_target)
if not jnp.allclose(_th_dd, _th_dd_target, rtol=RTOL, atol=ATOL):
    warnings.warn("The computed angular link accelerations are not correct.")
